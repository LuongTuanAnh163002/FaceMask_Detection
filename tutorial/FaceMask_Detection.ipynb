# %% [markdown]
# **1.Clone repository**

# %%
# !git clone https://github.com/LuongTuanAnh163002/FaceMask_Detection.git

# %% [markdown]
# **2.Dowload dataset**

# %%
# %cd FaceMask_Detection

# %%
# !gdown 1JXTeXB9YpyKad07NBQcpWLEMy7ue_iWd

# %%
# !unzip dataset.zip
# !rm dataset.zip

# %% [markdown]
# **3.Training model**

# %%
# !python train.py --epochs 1 --freeze
